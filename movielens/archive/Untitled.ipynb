# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as mpt
import seaborn as sns
# %matplotlib inline

# %%
df_rating=pd.read_csv('rating.csv',sep=';')
df_user=pd.read_csv('user.csv',sep=';')

# %%
df_movie=pd.read_csv('movies.csv',sep=';')
df_movie
# Out:
#       movieId                               title  \
# 0           1                    Toy Story (1995)
# 1           2                      Jumanji (1995)
# 2           3             Grumpier Old Men (1995)
# 3           4            Waiting to Exhale (1995)
# 4           5  Father of the Bride Part II (1995)
# ...       ...                                 ...
# 3878     3948             Meet the Parents (2000)
# 3879     3949          Requiem for a Dream (2000)
# 3880     3950                    Tigerland (2000)
# 3881     3951             Two Family House (2000)
# 3882     3952               Contender, The (2000)
#
#                             genres Unnamed: 3
# 0      Animation|Children's|Comedy        NaN
# 1     Adventure|Children's|Fantasy        NaN
# 2                   Comedy|Romance        NaN
# 3                     Comedy|Drama        NaN
# 4                           Comedy        NaN
# ...                            ...        ...
# ...

# %%
df_rating.head()
# Out:
#    userId  movieId  rating  timestamp
# 0       1     1193       5  978300760
# 1       1      661       3  978302109
# 2       1      914       3  978301968
# 3       1     3408       4  978300275
# 4       1     2355       5  978824291

# %%
df_user.head()
# Out:
#    userId gender  age  occupation zip-code
# 0       1      F    1          10    48067
# 1       2      M   56          16    70072
# 2       3      M   25          15    55117
# 3       4      M   45           7     2460
# 4       5      M   25          20    55455

# %%
filename=[df_movie,df_rating]
for files in filename:
    files=files.sort_values('movieId',ascending=True)

# %%
df_rating=df_rating.sort_values('userId',ascending=True)
df_user=df_user.sort_values('userId',ascending=True)
df_rating
# Out:
#          userId  movieId  rating  timestamp
# 0             1     1193       5  978300760
# 29            1      745       3  978824268
# 30            1     2294       4  978824291
# 31            1     3186       4  978300019
# 32            1     1566       4  978824330
# ...         ...      ...     ...        ...
# 999977     6040     1594       3  964828599
# 999976     6040     1587       1  956716374
# 999975     6040     3182       5  984195682
# 999983     6040      300       2  956704716
# 1000208    6040     1097       4  956715569
#
# [1000209 rows x 4 columns]

# %%
df_user
# Out:
#       userId gender  age  occupation zip-code
# 0          1      F    1          10    48067
# 1          2      M   56          16    70072
# 2          3      M   25          15    55117
# 3          4      M   45           7     2460
# 4          5      M   25          20    55455
# ...      ...    ...  ...         ...      ...
# 6035    6036      F   25          15    32603
# 6036    6037      F   45           1    76006
# 6037    6038      F   56           1    14706
# 6038    6039      F   45           0     1060
# 6039    6040      M   25           6    11106
#
# [6040 rows x 5 columns]

# %%
df_movie.head(13)
# Out:
#     movieId                               title                        genres  \
# 0         1                    Toy Story (1995)   Animation|Children's|Comedy
# 1         2                      Jumanji (1995)  Adventure|Children's|Fantasy
# 2         3             Grumpier Old Men (1995)                Comedy|Romance
# 3         4            Waiting to Exhale (1995)                  Comedy|Drama
# 4         5  Father of the Bride Part II (1995)                        Comedy
# 5         6                         Heat (1995)         Action|Crime|Thriller
# 6         7                      Sabrina (1995)                Comedy|Romance
# 7         8                 Tom and Huck (1995)          Adventure|Children's
# 8         9                 Sudden Death (1995)                        Action
# 9        10                    GoldenEye (1995)     Action|Adventure|Thriller
# 10       11      American President, The (1995)          Comedy|Drama|Romance
# ...

# %%
data=pd.merge(pd.merge(df_user,df_rating),df_movie)

# %%
data
# Out:
#          userId gender  age  occupation zip-code  movieId  rating  timestamp  \
# 0             1      F    1          10    48067     1193       5  978300760
# 1             2      M   56          16    70072     1193       5  978298413
# 2            12      M   25          12    32793     1193       4  978220179
# 3            15      M   25           7    22903     1193       4  978199279
# 4            17      M   50           1    95350     1193       5  978158471
# ...         ...    ...  ...         ...      ...      ...     ...        ...
# 1000204    5949      M   18          17    47901     2198       5  958846401
# 1000205    5675      M   35          14    30030     2703       3  976029116
# 1000206    5780      M   18          17    92886     2845       1  958153068
# 1000207    5851      F   18          20    55410     3607       5  957756608
# 1000208    5938      M   25           1    35401     2909       4  957273353
#
# ...

# %%
data=data.iloc[:,:-1]

# %%
data
# Out:
#          userId gender  age  occupation zip-code  movieId  rating  timestamp  \
# 0             1      F    1          10    48067     1193       5  978300760
# 1             2      M   56          16    70072     1193       5  978298413
# 2            12      M   25          12    32793     1193       4  978220179
# 3            15      M   25           7    22903     1193       4  978199279
# 4            17      M   50           1    95350     1193       5  978158471
# ...         ...    ...  ...         ...      ...      ...     ...        ...
# 1000204    5949      M   18          17    47901     2198       5  958846401
# 1000205    5675      M   35          14    30030     2703       3  976029116
# 1000206    5780      M   18          17    92886     2845       1  958153068
# 1000207    5851      F   18          20    55410     3607       5  957756608
# 1000208    5938      M   25           1    35401     2909       4  957273353
#
# ...

# %%
data.info
# Out:
# <bound method DataFrame.info of          userId gender  age  occupation zip-code  movieId  rating  timestamp  \
# 0             1      F    1          10    48067     1193       5  978300760
# 1             2      M   56          16    70072     1193       5  978298413
# 2            12      M   25          12    32793     1193       4  978220179
# 3            15      M   25           7    22903     1193       4  978199279
# 4            17      M   50           1    95350     1193       5  978158471
# ...         ...    ...  ...         ...      ...      ...     ...        ...
# 1000204    5949      M   18          17    47901     2198       5  958846401
# 1000205    5675      M   35          14    30030     2703       3  976029116
# 1000206    5780      M   18          17    92886     2845       1  958153068
# 1000207    5851      F   18          20    55410     3607       5  957756608
# 1000208    5938      M   25           1    35401     2909       4  957273353
#
# ...

# %%
import matplotlib
matplotlib.rcParams['figure.figsize']=(6,4)
sns.heatmap(data.isnull(),yticklabels=False,cbar=False)
# Out:
# <AxesSubplot:>

# %%
data.isnull().sum()
# Out:
# userId        0
# gender        0
# age           0
# occupation    0
# zip-code      0
# movieId       0
# rating        0
# timestamp     0
# title         0
# genres        0
# dtype: int64

# %%
data['title']
# Out:
# 0               One Flew Over the Cuckoo's Nest (1975)
# 1               One Flew Over the Cuckoo's Nest (1975)
# 2               One Flew Over the Cuckoo's Nest (1975)
# 3               One Flew Over the Cuckoo's Nest (1975)
# 4               One Flew Over the Cuckoo's Nest (1975)
#                               ...
# 1000204                             Modulations (1998)
# 1000205                          Broken Vessels (1998)
# 1000206                              White Boys (1999)
# 1000207                       One Little Indian (1973)
# 1000208    Five Wives, Three Secretaries and Me (1998)
# Name: title, Length: 1000209, dtype: object

# %%
mean_ratings = data.pivot_table('rating', index='title', columns='gender', aggfunc='mean')

# %%
mean_ratings
# Out:
# gender                                             F         M
# title
# $1,000,000 Duck (1971)                      3.375000  2.761905
# 'Night Mother (1986)                        3.388889  3.352941
# 'Til There Was You (1997)                   2.675676  2.733333
# 'burbs, The (1989)                          2.793478  2.962085
# ...And Justice for All (1979)               3.828571  3.689024
# ...                                              ...       ...
# Zed & Two Noughts, A (1985)                 3.500000  3.380952
# Zero Effect (1998)                          3.864407  3.723140
# Zero Kelvin (Kj�rlighetens kj�tere) (1995)       NaN  3.500000
# Zeus and Roxanne (1997)                     2.777778  2.357143
# eXistenZ (1999)                             3.098592  3.289086
#
# [3688 rows x 2 columns]

# %%
movie_rating=data.groupby('title').size()

# %%
movie_rating
# Out:
# title
# $1,000,000 Duck (1971)                         37
# 'Night Mother (1986)                           70
# 'Til There Was You (1997)                      52
# 'burbs, The (1989)                            303
# ...And Justice for All (1979)                 199
#                                              ...
# Zed & Two Noughts, A (1985)                    29
# Zero Effect (1998)                            301
# Zero Kelvin (Kj�rlighetens kj�tere) (1995)      2
# Zeus and Roxanne (1997)                        23
# eXistenZ (1999)                               410
# Length: 3688, dtype: int64

# %%
active_titles = movie_rating.index[movie_rating >= 250]

# %%
active_titles
# Out:
# Index([''burbs, The (1989)', '10 Things I Hate About You (1999)',
#        '101 Dalmatians (1961)', '101 Dalmatians (1996)', '12 Angry Men (1957)',
#        '13th Warrior, The (1999)', '2 Days in the Valley (1996)',
#        '20,000 Leagues Under the Sea (1954)', '2001', '2010 (1984)',
#        ...
#        'X-Men (2000)', 'Year of Living Dangerously (1982)',
#        'Yellow Submarine (1968)', 'You've Got Mail (1998)',
#        'Young Frankenstein (1974)', 'Young Guns (1988)',
#        'Young Guns II (1990)', 'Young Sherlock Holmes (1985)',
#        'Zero Effect (1998)', 'eXistenZ (1999)'],
#       dtype='object', name='title', length=1205)

# %%
for title in active_titles[:20]:
    print(title)
# Out:
# 'burbs, The (1989)
# 10 Things I Hate About You (1999)
# 101 Dalmatians (1961)
# 101 Dalmatians (1996)
# 12 Angry Men (1957)
# 13th Warrior, The (1999)
# 2 Days in the Valley (1996)
# 20,000 Leagues Under the Sea (1954)
# 2001
# 2010 (1984)
# 28 Days (2000)
# 39 Steps, The (1935)
# 54 (1998)
# 7th Voyage of Sinbad, The (1958)
# 8MM (1999)
# About Last Night... (1986)
# Absent Minded Professor, The (1961)
# Absolute Power (1997)
# Abyss, The (1989)
# Ace Ventura

# %%
mean_ratings = mean_ratings.loc[active_titles]

# %%
mean_ratings
# Out:
# gender                                    F         M
# title
# 'burbs, The (1989)                 2.793478  2.962085
# 10 Things I Hate About You (1999)  3.646552  3.311966
# 101 Dalmatians (1961)              3.791444  3.500000
# 101 Dalmatians (1996)              3.240000  2.911215
# 12 Angry Men (1957)                4.184397  4.328421
# ...                                     ...       ...
# Young Guns (1988)                  3.371795  3.425620
# Young Guns II (1990)               2.934783  2.904025
# Young Sherlock Holmes (1985)       3.514706  3.363344
# Zero Effect (1998)                 3.864407  3.723140
# eXistenZ (1999)                    3.098592  3.289086
#
# [1205 rows x 2 columns]

# %%
top_female_ratings = mean_ratings.sort_values(by="F", ascending=False)

# %%
top_female_ratings.head()
# Out:
# gender                                                F         M
# title
# Close Shave, A (1995)                          4.644444  4.473795
# Wrong Trousers, The (1993)                     4.588235  4.478261
# Sunset Blvd. (a.k.a. Sunset Boulevard) (1950)  4.572650  4.464589
# Wallace & Gromit                               4.563107  4.385075
# Schindler's List (1993)                        4.562602  4.491415

# %%
mean_ratings['diff'] = mean_ratings['M'] - mean_ratings['F']

# %%
mean_ratings
# Out:
# gender                                    F         M      diff
# title
# 'burbs, The (1989)                 2.793478  2.962085  0.168607
# 10 Things I Hate About You (1999)  3.646552  3.311966 -0.334586
# 101 Dalmatians (1961)              3.791444  3.500000 -0.291444
# 101 Dalmatians (1996)              3.240000  2.911215 -0.328785
# 12 Angry Men (1957)                4.184397  4.328421  0.144024
# ...                                     ...       ...       ...
# Young Guns (1988)                  3.371795  3.425620  0.053825
# Young Guns II (1990)               2.934783  2.904025 -0.030758
# Young Sherlock Holmes (1985)       3.514706  3.363344 -0.151362
# Zero Effect (1998)                 3.864407  3.723140 -0.141266
# eXistenZ (1999)                    3.098592  3.289086  0.190494
#
# [1205 rows x 3 columns]

# %%
sorted_by_diff = mean_ratings.sort_values(by="diff")
sorted_by_diff.head(10)
# Out:
# gender                                        F         M      diff
# title
# Dirty Dancing (1987)                   3.790378  2.959596 -0.830782
# Jumpin' Jack Flash (1986)              3.254717  2.578358 -0.676359
# Grease (1978)                          3.975265  3.367041 -0.608224
# Little Women (1994)                    3.870588  3.321739 -0.548849
# Steel Magnolias (1989)                 3.901734  3.365957 -0.535777
# Anastasia (1997)                       3.800000  3.281609 -0.518391
# Rocky Horror Picture Show, The (1975)  3.673016  3.160131 -0.512885
# Color Purple, The (1985)               4.158192  3.659341 -0.498851
# Age of Innocence, The (1993)           3.827068  3.339506 -0.487561
# Free Willy (1993)                      2.921348  2.438776 -0.482573

# %%
sorted_by_diff[::-1].head(10) # Men Prefered Films
# Out:
# gender                                         F         M      diff
# title
# Good, The Bad and The Ugly, The (1966)  3.494949  4.221300  0.726351
# Kentucky Fried Movie, The (1977)        2.878788  3.555147  0.676359
# Dumb & Dumber (1994)                    2.697987  3.336595  0.638608
# Longest Day, The (1962)                 3.411765  4.031447  0.619682
# Cable Guy, The (1996)                   2.250000  2.863787  0.613787
# Evil Dead II (Dead By Dawn) (1987)      3.297297  3.909283  0.611985
# Hidden, The (1987)                      3.137931  3.745098  0.607167
# Rocky III (1982)                        2.361702  2.943503  0.581801
# Caddyshack (1980)                       3.396135  3.969737  0.573602
# For a Few Dollars More (1965)           3.409091  3.953795  0.544704

# %%
rating_std_by_title = data.groupby('title')['rating'].std()

# %%
ratings_std_by_title = rating_std_by_title.loc[active_titles]

# %%
rating_std_by_title.sort_values(ascending=False).head(10)
# Out:
# title
# Foreign Student (1994)                                             2.828427
# Criminal Lovers (Les Amants Criminels) (1999)                      2.309401
# Talk of Angels (1998)                                              2.121320
# Tokyo Fist (1995)                                                  2.121320
# Paralyzing Fear                                                    2.121320
# Better Living (1998)                                               2.121320
# Identification of a Woman (Identificazione di una donna) (1982)    2.121320
# Neon Bible, The (1995)                                             2.121320
# Sunset Park (1996)                                                 2.121320
# Living Dead Girl, The (La Morte Vivante) (1982)                    2.121320
# Name: rating, dtype: float64

# %%
data
# Out:
#          userId gender  age  occupation zip-code  movieId  rating  timestamp  \
# 0             1      F    1          10    48067     1193       5  978300760
# 1             2      M   56          16    70072     1193       5  978298413
# 2            12      M   25          12    32793     1193       4  978220179
# 3            15      M   25           7    22903     1193       4  978199279
# 4            17      M   50           1    95350     1193       5  978158471
# ...         ...    ...  ...         ...      ...      ...     ...        ...
# 1000204    5949      M   18          17    47901     2198       5  958846401
# 1000205    5675      M   35          14    30030     2703       3  976029116
# 1000206    5780      M   18          17    92886     2845       1  958153068
# 1000207    5851      F   18          20    55410     3607       5  957756608
# 1000208    5938      M   25           1    35401     2909       4  957273353
#
# ...

# %%
data['gender'].hist(bins=25)
mpt.xlabel("gender")
mpt.ylabel('No.of people')
mpt.title('No. of people\'s ')
mpt.show()

# %%
sns.countplot(x=data.gender,hue=data.rating)
# Out:
# <AxesSubplot:xlabel='gender', ylabel='count'>

# %%
sns.barplot(x='age',y='rating',data=data)
# Out:
# <AxesSubplot:xlabel='age', ylabel='rating'>

# %% [markdown]
# # Extracting Years

# %%
df_movie
# Out:
#       movieId                               title  \
# 0           1                    Toy Story (1995)
# 1           2                      Jumanji (1995)
# 2           3             Grumpier Old Men (1995)
# 3           4            Waiting to Exhale (1995)
# 4           5  Father of the Bride Part II (1995)
# ...       ...                                 ...
# 3878     3948             Meet the Parents (2000)
# 3879     3949          Requiem for a Dream (2000)
# 3880     3950                    Tigerland (2000)
# 3881     3951             Two Family House (2000)
# 3882     3952               Contender, The (2000)
#
#                             genres Unnamed: 3
# 0      Animation|Children's|Comedy        NaN
# 1     Adventure|Children's|Fantasy        NaN
# 2                   Comedy|Romance        NaN
# 3                     Comedy|Drama        NaN
# 4                           Comedy        NaN
# ...                            ...        ...
# ...

# %%
years=[]
counts=0
for i in range(1,len(df_movie)):
    if((df_movie['title'][i][-5:-3]=='19')or(df_movie['title'][i][-5:-3]=='20')):
        year=int(df_movie['title'][i][-5:-1])
        years.append(year)
    else:
        years.append(0)
        counts+=1

# %%
count=0
for i in range(len(years)):
    if(years[i]==0):
        count+=1

# %%
count
# Out:
# 197

# %%
print(counts," ",len(years))
# Out:
# 197   3882

# %%
import matplotlib
matplotlib.rcParams['figure.figsize']=(39,6)
sns.countplot(x=years)
# Out:
# <AxesSubplot:ylabel='count'>

# %%
df_movie.head(20)
# Out:
#     movieId                               title                        genres  \
# 0         1                    Toy Story (1995)   Animation|Children's|Comedy
# 1         2                      Jumanji (1995)  Adventure|Children's|Fantasy
# 2         3             Grumpier Old Men (1995)                Comedy|Romance
# 3         4            Waiting to Exhale (1995)                  Comedy|Drama
# 4         5  Father of the Bride Part II (1995)                        Comedy
# 5         6                         Heat (1995)         Action|Crime|Thriller
# 6         7                      Sabrina (1995)                Comedy|Romance
# 7         8                 Tom and Huck (1995)          Adventure|Children's
# 8         9                 Sudden Death (1995)                        Action
# 9        10                    GoldenEye (1995)     Action|Adventure|Thriller
# 10       11      American President, The (1995)          Comedy|Drama|Romance
# ...

# %%
allyears=[]
counts=0
for i in range(1,len(df_movie)):
    if((df_movie['title'][i][-5:-3]=='19')or(df_movie['title'][i][-5:-3]=='20')):
        yearx=int(df_movie['title'][i][-5:-1])
        allyears.append(yearx)
    else:
        if((df_movie['genres'][i][-5:-3]=='19')or(df_movie['genres'][i][-5:-3]=='20')):
            yearx=int(df_movie['genres'][i][-5:-1])
            allyears.append(yearx)
            counts+=1

# %%
matplotlib.rcParams['figure.figsize']=(39,6)
sns.countplot(x=allyears)
# Out:
# <AxesSubplot:ylabel='count'>

# %%
count=0
for i in range(len(allyears)):
    if(allyears[i]==0):
        count+=1

# %%
count
# Out:
# 0

# %%
df_movie
# Out:
#       movieId                               title  \
# 0           1                    Toy Story (1995)
# 1           2                      Jumanji (1995)
# 2           3             Grumpier Old Men (1995)
# 3           4            Waiting to Exhale (1995)
# 4           5  Father of the Bride Part II (1995)
# ...       ...                                 ...
# 3878     3948             Meet the Parents (2000)
# 3879     3949          Requiem for a Dream (2000)
# 3880     3950                    Tigerland (2000)
# 3881     3951             Two Family House (2000)
# 3882     3952               Contender, The (2000)
#
#                             genres Unnamed: 3
# 0      Animation|Children's|Comedy        NaN
# 1     Adventure|Children's|Fantasy        NaN
# 2                   Comedy|Romance        NaN
# 3                     Comedy|Drama        NaN
# 4                           Comedy        NaN
# ...                            ...        ...
# ...

# %%
allyears=[]
counts=0
for i in range(0,len(df_movie)):
    if((df_movie['title'][i][-5:-3]=='19')or(df_movie['title'][i][-5:-3]=='20')):
        yearx=int(df_movie['title'][i][-5:-1])
        allyears.append(yearx)
    else:
        if((df_movie['genres'][i][-5:-3]=='19')or(df_movie['genres'][i][-5:-3]=='20')):
            yearx=int(df_movie['genres'][i][-5:-1])
            allyears.append(yearx)
            
        else:
             allyears.append(0)
             counts+=1

# %%
counts
# Out:
# 1

# %%
df_movie=df_movie.iloc[:,:-1]
df_movie
# Out:
#       movieId                               title  \
# 0           1                    Toy Story (1995)
# 1           2                      Jumanji (1995)
# 2           3             Grumpier Old Men (1995)
# 3           4            Waiting to Exhale (1995)
# 4           5  Father of the Bride Part II (1995)
# ...       ...                                 ...
# 3878     3948             Meet the Parents (2000)
# 3879     3949          Requiem for a Dream (2000)
# 3880     3950                    Tigerland (2000)
# 3881     3951             Two Family House (2000)
# 3882     3952               Contender, The (2000)
#
#                             genres
# 0      Animation|Children's|Comedy
# 1     Adventure|Children's|Fantasy
# 2                   Comedy|Romance
# 3                     Comedy|Drama
# 4                           Comedy
# ...                            ...
# 3878                        Comedy
# 3879                         Drama
# 3880                         Drama
# ...

# %%
pd.to_datetime(allyears)
df_movie['year']=pd.DatetimeIndex(allyears).year
for i in range(0,len(df_movie)):
    df_movie['year'][i]=allyears[i]
# Out:
# C:\Users\rrver\AppData\Local\Temp\ipykernel_8440\2162515320.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_movie['year'][i]=allyears[i]

# %%
df_movie.head(12)
# Out:
#     movieId                               title                        genres  \
# 0         1                    Toy Story (1995)   Animation|Children's|Comedy
# 1         2                      Jumanji (1995)  Adventure|Children's|Fantasy
# 2         3             Grumpier Old Men (1995)                Comedy|Romance
# 3         4            Waiting to Exhale (1995)                  Comedy|Drama
# 4         5  Father of the Bride Part II (1995)                        Comedy
# 5         6                         Heat (1995)         Action|Crime|Thriller
# 6         7                      Sabrina (1995)                Comedy|Romance
# 7         8                 Tom and Huck (1995)          Adventure|Children's
# 8         9                 Sudden Death (1995)                        Action
# 9        10                    GoldenEye (1995)     Action|Adventure|Thriller
# 10       11      American President, The (1995)          Comedy|Drama|Romance
# ...

# %%
updatedata=pd.merge(pd.merge(df_user,df_rating),df_movie)

# %%
updatedata
# Out:
#          userId gender  age  occupation zip-code  movieId  rating  timestamp  \
# 0             1      F    1          10    48067     1193       5  978300760
# 1             2      M   56          16    70072     1193       5  978298413
# 2            12      M   25          12    32793     1193       4  978220179
# 3            15      M   25           7    22903     1193       4  978199279
# 4            17      M   50           1    95350     1193       5  978158471
# ...         ...    ...  ...         ...      ...      ...     ...        ...
# 1000204    5949      M   18          17    47901     2198       5  958846401
# 1000205    5675      M   35          14    30030     2703       3  976029116
# 1000206    5780      M   18          17    92886     2845       1  958153068
# 1000207    5851      F   18          20    55410     3607       5  957756608
# 1000208    5938      M   25           1    35401     2909       4  957273353
#
# ...

# %%
categaries=[]
k=0
for i in range(len(df_movie)):
    k=0
    for j in range(len(df_movie['genres'][i])):
        if((df_movie['genres'][i][j])=='|'):
            value=(df_movie['genres'][i][k:j])
            print(value)
            categaries.append(value)
            k=j+1
        else:
            pass
    value=(df_movie['genres'][i][k:len(df_movie['genres'][i])])
    categaries.append(value)
    
    print(value)
# Out:
# Animation
# Children's
# Comedy
# Adventure
# Children's
# Fantasy
# Comedy
# Romance
# Comedy
# Drama
# Comedy
# Action
# Crime
# Thriller
# Comedy
# Romance
# Adventure
# Children's
# Action
# Action
# Adventure
# Thriller
# Comedy
# Drama
# Romance
#  Dead and Loving It (1995)
# Animation
# Children's
# Drama
# Action
# Adventure
# Romance
# Drama
# Thriller
# Drama
# Romance
# Thriller
#  When Nature Calls (1995)
# Action
# Action
# Comedy
# Drama
# Crime
# Drama
# Thriller
# Thriller
# Drama
# Sci-Fi
# Drama
# Romance
# Drama
# Drama
# Romance
# Adventure
# Sci-Fi
# Drama
# Drama
# Drama
# Sci-Fi
# Adventure
# Romance
# Children's
# Comedy
# Drama
# Drama
# Romance
# Drama
# Documentary
# Comedy
# Comedy
# Romance
# Drama
# Drama
# War
# Action
# Crime
# Drama
# Drama
# Action
# Adventure
# Comedy
# Drama
# Drama
# Romance
# Crime
# Thriller
# Animation
# Children's
# Musical
# Romance
# Drama
# Romance
# Crime
# Thriller
# Action
# Drama
# Thriller
# Comedy
# Drama
# ...

# %%
len(df_movie['genres'][10])
# Out:
# 20

# %%
df_movie['genres'][2]
# Out:
# 'Comedy|Romance'

# %%
categaries
# Out:
# {'e'}

# %%
categaries
# Out:
# {'Drama'}

# %%
value
# Out:
# 'Drama'

# %%
categaries
# Out:
# ['Animation',
#  "Children's",
#  'Comedy',
#  'Adventure',
#  "Children's",
#  'Fantasy',
#  'Comedy',
#  'Romance',
#  'Comedy',
#  'Drama',
#  'Comedy',
#  'Action',
#  'Crime',
#  'Thriller',
#  'Comedy',
#  'Romance',
#  'Adventure',
#  "Children's",
#  'Action',
#  'Action',
#  'Adventure',
#  'Thriller',
#  'Comedy',
#  'Drama',
#  'Romance',
#  ' Dead and Loving It (1995)',
#  'Animation',
#  "Children's",
#  'Drama',
#  'Action',
#  'Adventure',
#  'Romance',
#  'Drama',
#  'Thriller',
#  'Drama',
#  'Romance',
#  'Thriller',
#  ' When Nature Calls (1995)',
#  'Action',
#  'Action',
#  'Comedy',
#  'Drama',
#  'Crime',
#  'Drama',
#  'Thriller',
#  'Thriller',
#  'Drama',
#  'Sci-Fi',
#  'Drama',
#  'Romance',
#  'Drama',
#  'Drama',
#  'Romance',
#  'Adventure',
#  'Sci-Fi',
#  'Drama',
#  'Drama',
#  'Drama',
#  'Sci-Fi',
#  'Adventure',
#  'Romance',
#  "Children's",
#  'Comedy',
#  'Drama',
#  'Drama',
#  'Romance',
#  'Drama',
#  'Documentary',
#  'Comedy',
# ...

# %%
def unique(list1):
 
    unique_list = []
 
   
    for x in list1:
       
        if x not in unique_list:
            unique_list.append(x)
    for x in unique_list:
        if(len(x)>5):
            if((x[-5]=='1')or(x[-5]=='2')):
                x=''
            else:
                print(x)
unique(categaries)
# Out:
# Animation
# Children's
# Comedy
# Adventure
# Fantasy
# Romance
# Action
# Thriller
# Sci-Fi
# Documentary
# Musical
# Mystery
# Horror
# Film-Noir
# Western
#  Assignment

# %%
unique(categaries)
# Out:
# Animation
# Children's
# Comedy
# Adventure
# Fantasy
# Romance
# Action
# Thriller
# Sci-Fi
# Documentary
# Musical
# Mystery
# Horror
# Film-Noir
# Western
#  Assignment
